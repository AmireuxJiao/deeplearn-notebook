# %%
import numpy as np
np.__version__
# Out:
# '2.3.3'

# %%
data = {
    "a": 0,
    "b": [[1, 2], [3, 4]],
    "c": "string",
}

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

print(np.dot(A, B))
# Out:
# [[19 22]
#  [43 50]]
